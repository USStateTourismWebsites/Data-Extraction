# %%
import pandas as pd
from bs4 import BeautifulSoup
import json

# df = pd.read_parquet("../part-00000-8bcd0748-094a-4de0-8574-2328d1833c16-c000.gz.parquet", engine='pyarrow')
# df = pd.read_parquet("../part-00000-ae0248c1-9d9a-4943-8350-71a5267f9c51-c000.gz.parquet", engine='pyarrow')
df = pd.read_parquet("../part-00000-96ac3cdd-9fe4-4189-a066-f7b73d199c16-c000.gz.parquet", engine='pyarrow')
#df = pd.read_parquet("../part-00000-8ef97ec5-2cb7-4b7a-8a07-0935e967ee8e-c000.gz.parquet", engine='pyarrow')
df
# print("done")
# Out:
#                                                      key  \
# 0      http://(com,visitcalifornia,www,)/364Californi...
# 1      http://(com,visitcalifornia,www,)/6089Californ...
# 2      http://(com,visitcalifornia,www,)/11824Califor...
# 3      http://(com,visitcalifornia,www,)/17565Califor...
# 4      http://(com,visitcalifornia,www,)/18404Califor...
# ...                                                  ...
# 51799  https://(com,visitcalifornia,www,)/ca/destinat...
# 51800  https://(com,visitcalifornia,www,)/ca/destinat...
# 51801  http://(com,visitcalifornia,www,)/ca/destinati...
# 51802  http://(com,visitcalifornia,www,)/ca/destinati...
# 51803  http://(com,visitcalifornia,www,)/ca/destinati...
#
#                                                  surtUrl timestamp  \
# 0                     http://(com,visitcalifornia,www,)/  20071129
# 1                     http://(com,visitcalifornia,www,)/  20071227
# 2                     http://(com,visitcalifornia,www,)/  20080131
# 3                     http://(com,visitcalifornia,www,)/  20080228
# 4                     http://(com,visitcalifornia,www,)/  20080925
# ...                                                  ...       ...
# 51799  https://(com,visitcalifornia,www,)/ca/destinat...  20181224
# 51800  https://(com,visitcalifornia,www,)/ca/destinat...  20190301
# 51801  http://(com,visitcalifornia,www,)/ca/destinati...  20160404
# 51802  http://(com,visitcalifornia,www,)/ca/destinati...  20161028
# 51803  http://(com,visitcalifornia,www,)/ca/destinati...  20161222
#
#                                              originalUrl       mime status  \
# 0                        http://www.visitcalifornia.com/  text/html    200
# 1                        http://www.visitcalifornia.com/  text/html    200
# 2                        http://www.visitcalifornia.com/  text/html    200
# 3                        http://www.visitcalifornia.com/  text/html    301
# 4                        http://www.visitcalifornia.com/  text/html    301
# ...                                                  ...        ...    ...
# 51799  https://www.visitcalifornia.com/ca/destination...  text/html    200
# 51800  https://www.visitcalifornia.com/ca/destination...  text/html    200
# 51801  http://www.visitcalifornia.com/ca/destination/...  text/html    200
# 51802  http://www.visitcalifornia.com/ca/destination/...  text/html    200
# 51803  http://www.visitcalifornia.com/ca/destination/...  text/html    200
#
#       digest redirectUrl meta  contentLength      offset  \
# 0          -           -    -          21289         364
# 1          -           -    -          21160        6089
# 2          -           -    -          21210       11824
# 3          -           -    -            958       17565
# 4          -           -    -           1127       18404
# ...      ...         ...  ...            ...         ...
# 51799      -           -    -         114422  1073632420
# 51800      -           -    -         116359  1073653742
# 51801      -           -    -         123751  1073675638
# 51802      -           -    -         127168  1073695328
# 51803      -           -    -         152819  1073715955
#
#                                                 filename  \
# 0      California2_www-visitcalifornia-com_200103-201...
# 1      California2_www-visitcalifornia-com_200103-201...
# 2      California2_www-visitcalifornia-com_200103-201...
# 3      California2_www-visitcalifornia-com_200103-201...
# 4      California2_www-visitcalifornia-com_200103-201...
# ...                                                  ...
# 51799  California2_www-visitcalifornia-com_200103-201...
# 51800  California2_www-visitcalifornia-com_200103-201...
# 51801  California2_www-visitcalifornia-com_200103-201...
# 51802  California2_www-visitcalifornia-com_200103-201...
# 51803  California2_www-visitcalifornia-com_200103-201...
#
#                                                allheader  \
# 0      file:/home/xw0078/data/tourism-data/vt-tourism...
# 1      file:/home/xw0078/data/tourism-data/vt-tourism...
# 2      file:/home/xw0078/data/tourism-data/vt-tourism...
# 3      file:/home/xw0078/data/tourism-data/vt-tourism...
# 4      file:/home/xw0078/data/tourism-data/vt-tourism...
# ...                                                  ...
# 51799  file:/home/xw0078/data/tourism-data/vt-tourism...
# 51800  file:/home/xw0078/data/tourism-data/vt-tourism...
# 51801  file:/home/xw0078/data/tourism-data/vt-tourism...
# 51802  file:/home/xw0078/data/tourism-data/vt-tourism...
# 51803  file:/home/xw0078/data/tourism-data/vt-tourism...
#
#                                                  payload
# 0      HTTP/1.1 200 OK\r\nDate: Thu, 29 Nov 2007 13:2...
# 1      HTTP/1.1 200 OK\r\nDate: Thu, 27 Dec 2007 10:5...
# 2      HTTP/1.1 200 OK\r\nDate: Thu, 31 Jan 2008 23:2...
# 3      HTTP/1.1 301 Moved Permanently\r\nConnection: ...
# 4      HTTP/1.1 301 Moved Permanently\r\nConnection: ...
# ...                                                  ...
# 51799  HTTP/1.1 200 OK\r\nDate: Mon, 24 Dec 2018 11:5...
# 51800  HTTP/1.1 200 OK\r\nDate: Fri, 01 Mar 2019 00:4...
# 51801  HTTP/1.1 200 OK\r\nServer: nginx\r\nContent-Ty...
# 51802  HTTP/1.1 200 OK\r\nDate: Fri, 28 Oct 2016 22:2...
# 51803  HTTP/1.1 200 OK\r\nDate: Thu, 22 Dec 2016 02:0...
#
# [51804 rows x 14 columns]

# %%
df.timestamp[0]
# Out:
# '20071129'

# %%
# df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format=True)

# %%
def headerAndTime(df):
    #list that will hold information for every row 
    tableInfo = []
    #list that will hold indices of rows with errors
    errors = []
    for row in range(df.shape[0]):
        try:
            #dictionary to store information from the row
            quickDict = {}
            #grabbing information from each column of the row
            quickDict["Row"] = row
            soup = BeautifulSoup(df.payload[row], 'html.parser')
            quickDict["Header"] = soup.title.text
            quickDict["Timestamp"] = df.timestamp[row]
            quickDict["URL"] = df.originalUrl[row]
            tableInfo.append(quickDict)
        except AttributeError:
            #some rows don't have an HTML file in the payload
            #when trying to use soup.title.text above, it will give an AttributeError because it has no title.text attribute
            #this exception adds the row index to a list titled "errors" to be able to see which rows had the error in case it's needed
            errors.append(row)
    return tableInfo, errors

# %%
tableInfo, errors = headerAndTime(df)

# %%
print(len(errors))
# Out:
# 5671

# %%
import csv
csv_columns = ['Row','Header','Timestamp', 'URL']
csv_file = "headerTimestampUrl3.csv"
try:
    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in tableInfo:
            writer.writerow(data)
except IOError:
    print("I/O error")
