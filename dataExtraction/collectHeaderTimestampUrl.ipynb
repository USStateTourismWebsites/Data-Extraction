# %%
import pandas as pd
from bs4 import BeautifulSoup
import json
# df = pd.read_parquet("../data/part1.gz.parquet", engine='pyarrow')
# df = pd.read_parquet("../data/part2.gz.parquet", engine='pyarrow')
# df = pd.read_parquet("../data/part3.gz.parquet", engine='pyarrow')
df = pd.read_parquet("../data/part4.gz.parquet", engine='pyarrow')
df
# print("done")
# Out:
#                                                      key  \
# 0      http://(com,visitcalifornia,www,)/node/16026/m...
# 1      http://(com,visitcalifornia,www,)/node/16026/m...
# 2      http://(com,visitcalifornia,www,)/node/16026/m...
# 3      http://(com,visitcalifornia,www,)/node/16026/m...
# 4      http://(com,visitcalifornia,www,)/node/16026/m...
# ...                                                  ...
# 48804  http://(com,visitcalifornia,yearinreview,)/doc...
# 48805  http://(com,visitcalifornia,yearinreview,)/fav...
# 48806  https://(com,visitcalifornia,yearinreview,)/ro...
# 48807  https://(com,visitcalifornia,yearinreview,)/ro...
# 48808  http://(com,visitcalifornia,yir,)/robots.txt81...
#
#                                                  surtUrl timestamp  \
# 0      http://(com,visitcalifornia,www,)/node/16026/m...  20161224
# 1      http://(com,visitcalifornia,www,)/node/16026/m...  20170926
# 2      http://(com,visitcalifornia,www,)/node/16026/m...  20161226
# 3      http://(com,visitcalifornia,www,)/node/16026/m...  20161226
# 4      http://(com,visitcalifornia,www,)/node/16026/m...  20161226
# ...                                                  ...       ...
# 48804  http://(com,visitcalifornia,yearinreview,)/doc...  20161202
# 48805  http://(com,visitcalifornia,yearinreview,)/fav...  20150907
# 48806  https://(com,visitcalifornia,yearinreview,)/ro...  20170817
# 48807  https://(com,visitcalifornia,yearinreview,)/ro...  20180519
# 48808       http://(com,visitcalifornia,yir,)/robots.txt  20171010
#
#                                              originalUrl       mime status  \
# 0      http://www.visitcalifornia.com/node/16026/more...  text/html    200
# 1      http://www.visitcalifornia.com/node/16026/more...  text/html    200
# 2      http://www.visitcalifornia.com/node/16026/more...  text/html    200
# 3      http://www.visitcalifornia.com/node/16026/more...  text/html    200
# 4      http://www.visitcalifornia.com/node/16026/more...  text/html    200
# ...                                                  ...        ...    ...
# 48804  http://yearinreview.visitcalifornia.com/docs/t...  text/html    404
# 48805  http://yearinreview.visitcalifornia.com/favico...  text/html    404
# 48806  https://yearinreview.visitcalifornia.com/robot...  text/html    404
# 48807  https://yearinreview.visitcalifornia.com/robot...  text/html    404
# 48808          http://yir.visitcalifornia.com/robots.txt  text/html    404
#
#       digest redirectUrl meta  contentLength     offset  \
# 0          -           -    -          81764        363
# 1          -           -    -          85985      14805
# 2          -           -    -          81216      29968
# 3          -           -    -          81509      44347
# 4          -           -    -          81650      58753
# ...      ...         ...  ...            ...        ...
# 48804      -           -    -          51408  818558951
# 48805      -           -    -           1813  818578807
# 48806      -           -    -            336  818580081
# 48807      -           -    -            336  818580560
# 48808      -           -    -            336  818581037
#
#                                                 filename  \
# 0      California2_www-visitcalifornia-com_200103-201...
# 1      California2_www-visitcalifornia-com_200103-201...
# 2      California2_www-visitcalifornia-com_200103-201...
# 3      California2_www-visitcalifornia-com_200103-201...
# 4      California2_www-visitcalifornia-com_200103-201...
# ...                                                  ...
# 48804  California2_www-visitcalifornia-com_200103-201...
# 48805  California2_www-visitcalifornia-com_200103-201...
# 48806  California2_www-visitcalifornia-com_200103-201...
# 48807  California2_www-visitcalifornia-com_200103-201...
# 48808  California2_www-visitcalifornia-com_200103-201...
#
#                                                allheader  \
# 0      file:/home/xw0078/data/tourism-data/vt-tourism...
# 1      file:/home/xw0078/data/tourism-data/vt-tourism...
# 2      file:/home/xw0078/data/tourism-data/vt-tourism...
# 3      file:/home/xw0078/data/tourism-data/vt-tourism...
# 4      file:/home/xw0078/data/tourism-data/vt-tourism...
# ...                                                  ...
# 48804  file:/home/xw0078/data/tourism-data/vt-tourism...
# 48805  file:/home/xw0078/data/tourism-data/vt-tourism...
# 48806  file:/home/xw0078/data/tourism-data/vt-tourism...
# 48807  file:/home/xw0078/data/tourism-data/vt-tourism...
# 48808  file:/home/xw0078/data/tourism-data/vt-tourism...
#
#                                                  payload
# 0      HTTP/1.1 200 OK\r\nDate: Sat, 24 Dec 2016 10:0...
# 1      HTTP/1.1 200 OK\r\nDate: Tue, 26 Sep 2017 05:0...
# 2      HTTP/1.1 200 OK\r\nDate: Mon, 26 Dec 2016 10:2...
# 3      HTTP/1.1 200 OK\r\nDate: Mon, 26 Dec 2016 10:2...
# 4      HTTP/1.1 200 OK\r\nDate: Mon, 26 Dec 2016 04:3...
# ...                                                  ...
# 48804  HTTP/1.0 404 Not Found\r\nDate: Fri, 02 Dec 20...
# 48805  HTTP/1.1 404 Not Found\r\nContent-Length: 1635...
# 48806  HTTP/1.1 404 Not Found\r\nServer: nginx/1.10.3...
# 48807  HTTP/1.1 404 Not Found\r\nServer: nginx/1.10.3...
# 48808  HTTP/1.1 404 Not Found\r\nServer: nginx/1.10.3...
#
# [48809 rows x 14 columns]

# %%
df.payload[0]
# Out:
# 'HTTP/1.1 200 OK\r\nDate: Wed, 15 Feb 2017 12:48:58 GMT\r\nContent-Type: text/html; charset=utf-8\r\nConnection: close\r\nSet-Cookie: __cfduid=ddd9000cfabad413a5b4f517b9a660ba11487162938; expires=Thu, 15-Feb-18 12:48:58 GMT; path=/; domain=.visitcalifornia.com; HttpOnly\r\nX-Drupal-Cache: MISS\r\nX-Content-Type-Options: nosniff\r\nX-Frame-Options: SameOrigin\r\nContent-Language: en-ca\r\nX-UA-Compatible: IE=edge\r\nLink: <http://www.visitcalifornia.com/node/1156>; rel="alternate"; hreflang="x-default",<http://www.visitcalifornia.com/ca/destination/spotlight-hearst-castle>; rel="canonical"\r\nCache-Control: public, max-age=21600\r\nLast-Modified: Wed, 15 Feb 2017 07:08:07 GMT\r\nExpires: Sun, 19 Nov 1978 05:00:00 GMT\r\nVary: Cookie,Accept-Encoding\r\nX-Request-ID: v-8040eac6-f34d-11e6-990f-22000b0053f1\r\nX-AH-Environment: prod\r\nX-Varnish: 2624540459 2622577708\r\nVia: 1.1 varnish\r\nX-Cache: HIT\r\nX-Cache-Hits: 3\r\nCF-Cache-Status: EXPIRED\r\nServer: cloudflare-nginx\r\nCF-RAY: 3318e08ff63a6bf2-SJC\r\n\r\n<!DOCTYPE html>\n<!--[if IEMobile 7]><html class="iem7"  lang="en-ca" dir="ltr"><![endif]-->\n<!--[if lte IE 6]><html class="lt-ie10 lt-ie9 lt-ie8 lt-ie7"  lang="en-ca" dir="ltr"><![endif]-->\n<!--[if (IE 7)&(!IEMobile)]><html class="lt-ie10 lt-ie9 lt-ie8"  lang="en-ca" dir="ltr"><![endif]-->\n<!--[if IE 8]><html class="lt-ie9 lt-ie10"  lang="en-ca" dir="ltr"><![endif]-->\n<!--[if IE 9]><html class="lt-ie10"  lang="en-ca" dir="ltr"><![endif]-->\n<!--[if IE 10]><html class="lte-ie10"  lang="en-ca" dir="ltr"><![endif]-->\n<!--[if (gt IE 9)|(gt IEMobile 7)]><!--><html  lang="en-ca" dir="ltr" prefix="fb: http://www.facebook.com/2008/fbml og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product# content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#"><!--<![endif]-->\n\n<head>\n  <meta charset="utf-8" />\n<link rel="alternate" hreflang="es-mx" href="http://www.visitcalifornia.com/mx/destination/castillo-hearst" />\n<link rel="alternate" hreflang="it" href="http://www.visitcalifornia.com/it/destination/focus-hearst-castle" />\n<link rel="alternate" hreflang="en-gb" href="http://www.visitcalifornia.com/uk/destination/spotlight-hearst-castle" />\n<link rel="alternate" hreflang="fr" href="http://www.visitcalifornia.com/fr/destination/spotlight-hearst-castle" />\n<link rel="alternate" hreflang="zh-hans" href="http://www.visitcalifornia.com/cn/destination/聚焦：赫氏古堡" />\n<link rel="shortcut icon" href="//d14dsi4x2zx6ql.cloudfront.net/sites/all/themes/vca/images/favicon.ico" type="image/vnd.microsoft.icon" />\n<link rel="alternate" hreflang="ko" href="http://www.visitcalifornia.com/kr/destination/spotlight-허스트-캐슬" />\n<link rel="alternate" hreflang="ja" href="http://www.visitcalifornia.com/jp/destination/spotlight-ハースト・キャッスル" />\n<link rel="alternate" hreflang="de" href="http://www.visitcalifornia.com/de/destination/spotlight-hearst-castle" />\n<link rel="alternate" hreflang="en-in" href="http://www.visitcalifornia.com/in/destination/spotlight-hearst-castle" />\n<link rel="alternate" hreflang="en-ca" href="http://www.visitcalifornia.com/ca/destination/spotlight-hearst-castle" />\n<meta http-equiv="x-dns-prefetch-control" content="on" />\n<link rel="dns-prefetch" href="//d14dsi4x2zx6ql.cloudfront.net" />\n<link rel="alternate" hreflang="pt-br" href="http://www.visitcalifornia.com/br/destination/destaque-castelo-hearst" />\n<link rel="alternate" hreflang="en-au" href="http://www.visitcalifornia.com/au/destination/spotlight-hearst-castle" />\n<link rel="alternate" hreflang="en" href="http://www.visitcalifornia.com/destination/spotlight-hearst-castle" />\n<link rel="a ...

# %%
# df['timestamp'] = pd.to_datetime(df['timestamp'], infer_datetime_format=True)

# %%
def headerAndTime(df):
    #list that will hold information for every row 
    tableInfo = []
    #list that will hold indices of rows with errors
    errors = []
    for row in range(df.shape[0]):
        try:
            #dictionary to store information from the row
            quickDict = {}
            #grabbing information from each column of the row
            quickDict["Row"] = row
            soup = BeautifulSoup(df.payload[row], 'html.parser')
            quickDict["Header"] = soup.title.text
            quickDict["Timestamp"] = df.timestamp[row]
            quickDict["URL"] = df.originalUrl[row]
            tableInfo.append(quickDict)
        except AttributeError:
            #some rows don't have an HTML file in the payload
            #when trying to use soup.title.text above, it will give an AttributeError because it has no title.text attribute
            #this exception adds the row index to a list titled "errors" to be able to see which rows had the error in case it's needed
            errors.append(row)
    return tableInfo, errors

# %%
tableInfo, errors = headerAndTime(df)

# %%
print(len(errors))
# Out:
# 7888

# %%
import csv
csv_columns = ['Row','Header','Timestamp', 'URL']
csv_file = "headerTimestampUrl4.csv"
try:
    with open(csv_file, 'w') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for data in tableInfo:
            writer.writerow(data)
except IOError:
    print("I/O error")
